# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
movie = pd.read_csv('movies.csv')
movie.shape
# Out:
# (9742, 3)

# %%
ratings = pd.read_csv('ratings.csv')
ratings.shape
# Out:
# (100836, 4)

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
ratings['userId'].unique()

# %%
ratings.head(10)
ratings.sort_values(by=['rating'])
# Out:
#        userId  movieId  rating   timestamp
# 3752       22    53519     0.5  1268727137
# 60861     393     5445     0.5  1430506636
# 47025     307     2017     0.5  1186173639
# 22446     153     1198     0.5  1525548264
# 60865     393     5902     0.5  1430507509
# ...       ...      ...     ...         ...
# 90260     587       50     5.0   953141366
# 90261     587       58     5.0   953141592
# 17061     108     5303     5.0  1042839719
# 90266     587      236     5.0   953139541
# 81530     516     4429     5.0   994625299
#
# [100836 rows x 4 columns]

# %%
n = len(pd.unique(ratings['userId']))
n
# Out:
# 610

# %%
movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
tags = pd.read_csv('tags.csv')
tags.shape
# Out:
# (3683, 4)

# %%
links = pd.read_csv('links.csv')
links.shape
# Out:
# (9742, 3)

# %%
movie_ratings = pd.concat([movie , ratings],axis=0)
movie_ratings
# Out:
#         movieId                               title  \
# 0             1                    Toy Story (1995)
# 1             2                      Jumanji (1995)
# 2             3             Grumpier Old Men (1995)
# 3             4            Waiting to Exhale (1995)
# 4             5  Father of the Bride Part II (1995)
# ...         ...                                 ...
# 100831   166534                                 NaN
# 100832   168248                                 NaN
# 100833   168250                                 NaN
# 100834   168252                                 NaN
# 100835   170875                                 NaN
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy     NaN     NaN
# 1                        Adventure|Children|Fantasy     NaN     NaN
# 2                                    Comedy|Romance     NaN     NaN
# ...

# %%
movie_tags = pd.concat([movie,tags],axis=0)
movie_tags
# Out:
#       movieId                               title  \
# 0           1                    Toy Story (1995)
# 1           2                      Jumanji (1995)
# 2           3             Grumpier Old Men (1995)
# 3           4            Waiting to Exhale (1995)
# 4           5  Father of the Bride Part II (1995)
# ...       ...                                 ...
# 3678     7382                                 NaN
# 3679     7936                                 NaN
# 3680     3265                                 NaN
# 3681     3265                                 NaN
# 3682   168248                                 NaN
#
#                                            genres  userId               tag  \
# 0     Adventure|Animation|Children|Comedy|Fantasy     NaN               NaN
# 1                      Adventure|Children|Fantasy     NaN               NaN
# 2                                  Comedy|Romance     NaN               NaN
# ...

# %%
movie_ratings.describe()
# Out:
#              movieId         userId         rating     timestamp
# count  110578.000000  100836.000000  100836.000000  1.008360e+05
# mean    21440.913419     326.127564       3.501557  1.205946e+09
# std     37848.880654     182.618491       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%      1221.000000     177.000000       3.000000  1.019124e+09
# 50%      3254.000000     325.000000       3.500000  1.186087e+09
# 75%      8961.000000     477.000000       4.000000  1.435994e+09
# max    193609.000000     610.000000       5.000000  1.537799e+09

# %%
user_freq = ratings[['userId', 'movieId']].groupby(
    'userId').count().reset_index()
user_freq.columns = ['userId', 'n_ratings']
user_freq
# Out:
#      userId  n_ratings
# 0         1        232
# 1         2         29
# 2         3         39
# 3         4        216
# 4         5         44
# ..      ...        ...
# 605     606       1115
# 606     607        187
# 607     608        831
# 608     609         37
# 609     610       1302
#
# [610 rows x 2 columns]

# %%
user_freq.describe()
# Out:
#            userId    n_ratings
# count  610.000000   610.000000
# mean   305.500000   165.304918
# std    176.236111   269.480584
# min      1.000000    20.000000
# 25%    153.250000    35.000000
# 50%    305.500000    70.500000
# 75%    457.750000   168.000000
# max    610.000000  2698.000000

# %%
movie = pd.concat(user_freq, left_on=['movieId','genres'], right_on=['userId' ,'n_ratings'],how='inner')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_50208/1098139651.py in <module>
# ----> 1 movie = pd.concat(user_freq, left_on=['movieId','genres'], right_on=['userId' ,'n_ratings'],how='inner')
#
# E:\Anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: concat() got an unexpected keyword argument 'left_on'

# %%
movie_operations = pd.concat([user_freq,movie],axis=0)
movie_operations
# Out:
#       userId  n_ratings   movieId                                      title  \
# 0        1.0      232.0       NaN                                        NaN
# 1        2.0       29.0       NaN                                        NaN
# 2        3.0       39.0       NaN                                        NaN
# 3        4.0      216.0       NaN                                        NaN
# 4        5.0       44.0       NaN                                        NaN
# ...      ...        ...       ...                                        ...
# 9737     NaN        NaN  193581.0  Black Butler: Book of the Atlantic (2017)
# 9738     NaN        NaN  193583.0               No Game No Life: Zero (2017)
# 9739     NaN        NaN  193585.0                               Flint (2017)
# 9740     NaN        NaN  193587.0        Bungo Stray Dogs: Dead Apple (2018)
# 9741     NaN        NaN  193609.0        Andrew Dice Clay: Dice Rules (1991)
#
#                                genres
# ...

# %%
movie_operations.head()
# Out:
#    userId  n_ratings  movieId title genres
# 0     1.0      232.0      NaN   NaN    NaN
# 1     2.0       29.0      NaN   NaN    NaN
# 2     3.0       39.0      NaN   NaN    NaN
# 3     4.0      216.0      NaN   NaN    NaN
# 4     5.0       44.0      NaN   NaN    NaN

# %%
n_ratings.ascending()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_50208/3089529346.py in <module>
# ----> 1 n_ratings.ascending()
#
# NameError: name 'n_ratings' is not defined

# %%
sort_ratings = movie_operations.sort_values(by=['n_ratings'])

# %%
sort_ratings.head(40)
# Out:
#      userId  n_ratings  movieId title genres
# 441   442.0       20.0      NaN   NaN    NaN
# 405   406.0       20.0      NaN   NaN    NaN
# 146   147.0       20.0      NaN   NaN    NaN
# 193   194.0       20.0      NaN   NaN    NaN
# 568   569.0       20.0      NaN   NaN    NaN
# 575   576.0       20.0      NaN   NaN    NaN
# 430   431.0       20.0      NaN   NaN    NaN
# 206   207.0       20.0      NaN   NaN    NaN
# 277   278.0       20.0      NaN   NaN    NaN
# 319   320.0       20.0      NaN   NaN    NaN
# 52     53.0       20.0      NaN   NaN    NaN
# 594   595.0       20.0      NaN   NaN    NaN
# 188   189.0       20.0      NaN   NaN    NaN
# 256   257.0       20.0      NaN   NaN    NaN
# 25     26.0       21.0      NaN   NaN    NaN
# 86     87.0       21.0      NaN   NaN    NaN
# 546   547.0       21.0      NaN   NaN    NaN
# 280   281.0       21.0      NaN   NaN    NaN
# 506   507.0       21.0      NaN   NaN    NaN
# 36     37.0       21.0      NaN   NaN    NaN
# ...
